# %% [markdown]
# ### DSN AI+ FUTA
# ### Python Basics

# %% [markdown]
# ### Variables and Datatypes
#
# *Variables are place holders, they are specifica and case sensitive. Values can be called through their variable names. For example*

# %%
# Note: in python Variables cannot start with numbers or special character such as @.;''
name_of_var = 2
weight = 3

# %%
name_of_var
# Out:
# 2

# %%
name_of_var = 5

# %%
name_of_var
# Out:
# 5

# %%
weight
# Out:
# 3

# %%
name_of_var
# Out:
# 5

# %%
x = 2
y = 3

# %% [markdown]
# ### Arithmetic Operations and comparison in Python

# %%
z = x + y

# %%
z
# Out:
# 5

# %%
subt = x-y
subt
# Out:
# -1

# %%
mult = x*y
mult
# Out:
# 6

# %% [markdown]
# ### Datatypes

# %%
#Intergers are positive and negative whole number
x = 4
type(x)
# Out:
# int

# %%
#Float or floating point numbers in other programming language
y= 3.15
type(y)
# Out:
# float

# %%
u = 42.78901
u
# Out:
# 42.78901

# %%
type(u)
# Out:
# float

# %%
#boolean: they are usualy true or false
z= x > y
type(z)
# Out:
# bool

# %%
#Comparison
x= 5
y = 10
r = x > y

# %%
r
# Out:
# False

# %%
x == y
# Out:
# False

# %%
#Strings are pythons way to represent text. They are usually enclosed in double or single quotes
name = "My name is Grace"
type(name)
# Out:
# str

# %% [markdown]
# ### Numbers and mathematical operators

# %%
#Addition
1 + 1
# Out:
# 2

# %%
#Multiplication
1 * 3
# Out:
# 3

# %%
#Division
1/2
# Out:
# 0.5

# %%
#Exponential
2**4
# Out:
# 16

# %%
#Another way to perform exponential or power operation
pow(2, 4)
# Out:
# 16

# %%
#mod
4 % 2
# Out:
# 0

# %%
5 % 2
# Out:
# 1

# %% [markdown]
# ####  PEDMAS
#
# P -  Parenthesis
# E- Exponential
# D- Division
# M - Multiplication
# A - Addition
# S - Subtraction

# %%
 5 * 4**(5/8) + 2 - 9
# Out:
# 4.89207115002721

# %%
 operation = (((5 * ((4**5)/8)) + 2) - 9)

# %%
operation
# Out:
# 633.0

# %%
(2 + 3) * (5 + 5)
# Out:
# 50

# %% [markdown]
# ## Strings

# %%
'single quotes'
# Out:
# 'single quotes'

# %%
"double qoutes"
# Out:
# 'double qoutes'

# %%
"wrap lot's of other quotes"
# Out:
# "wrap lot's of other quotes"

# %% [markdown]
# #### Note the plus operator behaves differently for different datatypes. This is a general principle

# %%
'ab' + 'bd'
# Out:
# 'abbd'

# %% [markdown]
# ## Printing

# %%
x = 'hello'

# %%
x
# Out:
# 'hello'

# %%
print(x)
# Out:
# hello

# %%
num = 10
name = "Grace"

# %%
name = "Goodness"
matricNo = 20152355

# %%
#Using .format() is a funtion that only works in python 3
print("My name is {name1} and my matric number is {matricNo1}".format(name1 = name, matricNo1 = matricNo))
# Out:
# My name is Goodness and my matric number is 20152355

# %%
print("My name is {} and my matric number is {}".format(name,matricNo))
# Out:
# My name is Goodness and my matric number is 20152355

# %%
print("My number is: {one}, and my name is: {two}".format(one=num,two=name))
# Out:
# My number is: 10, and my name is: Goodness

# %%
print("My number is: {}, and my name is: {}".format(num,name))
# Out:
# My number is: 10, and my name is: Goodness

# %%
print("My name is ", name)
# Out:
# My name is  Goodness

# %% [markdown]
# ## Lists

# %% [markdown]
# ### As a data scientist you often want to work with many datapoints, not just single variable. For example you want to store the score of 10  students ???

# %%
### Without Lists
Student1 = 10
Student2 = 9
Student3 = 8
Student5 = 9
Student6 = 7
Student10 = 10

# %%
#List
name = ["Greg", "John"]
name
# Out:
# ['Greg', 'John']

# %%
type(name)
# Out:
# list

# %%
# With List
studentScore = [10,9,8,9,7,10]
studentScore
# Out:
# [10, 9, 8, 9, 7, 10]

# %%
[1,2, 3]
# Out:
# [1, 2, 3]

# %% [markdown]
# ### A list is a way to give a single name to a collection of values. These values are elements of any type, it can be float, integers, strings, or another list (list Comprehension)!
#
# ***Note it is possible for a list to contain different data types***

# %%
studentScore = ['Student1', 10, 'Student2', 5, 'Student3', 6, 'Student4', 7, 'Student5', 10]

# %%
studentScore
# Out:
# ['Student1', 10, 'Student2', 5, 'Student3', 6, 'Student4', 7, 'Student5', 10]

# %%
height = [["Kola", 3.14], ["George", 6.76]]
height
# Out:
# [['Kola', 3.14], ['George', 6.76]]

# %%
type(height)
# Out:
# list

# %% [markdown]
# #### List inside another list

# %%
score2 = [['Student1', 10], ['Student2', 5], ['Student3', 6], ['Student4', 7], ['Student5', 10]]
score2
# Out:
# [['Student1', 10],
#  ['Student2', 5],
#  ['Student3', 6],
#  ['Student4', 7],
#  ['Student5', 10]]

# %% [markdown]
# #### 5 sublist in 1 list

# %%
type(studentScore)
# Out:
# list

# %%
type(score2)
# Out:
# list

# %%
country = ["Nigeria", "Ghana", "France", "Cameron", "Hungary", "Saudi Arabia", "Israel", ["Jerusalem", "USA"]]

# %%
country
# Out:
# ['Nigeria',
#  'Ghana',
#  'France',
#  'Cameron',
#  'Hungary',
#  'Saudi Arabia',
#  'Israel',
#  ['Jerusalem', 'USA']]

# %%
Nations = country[0:4]
Nations
# Out:
# ['Nigeria', 'Ghana', 'France', 'Cameron']

# %%
['hi', 1, [1, 2]]
# Out:
# ['hi', 1, [1, 2]]

# %%
type(country)
# Out:
# list

# %% [markdown]
# ### Subsetting List
#
# #### Python uses zero base indexing to retrieve an element from a list

# %%
studentScore
# Out:
# ['Student1', 10, 'Student2', 5, 'Student3', 6, 'Student4', 7, 'Student5', 10]

# %%
studentScore[3]
# Out:
# 5

# %%
# used to retrieve element at the end of a list
studentScore[-1]
# Out:
# 10

# %% [markdown]
# #### List slicing - Creating a new list from a list or selecting multiple indexes using :

# %%
studentScore
# Out:
# ['Student1', 10, 'Student2', 5, 'Student3', 6, 'Student4', 7, 'Student5', 10]

# %%
# last element not inclusive i.e [start:end-1]
studentScore[3:5]
# Out:
# [5, 'Student3']

# %%
# subsetting first four element, Note the last element is not included
studentScore[:4]
# Out:
# ['Student1', 10, 'Student2', 5]

# %%
# subsetting 5 to the end
studentScore[5:]
# Out:
# [6, 'Student4', 7, 'Student5', 10]

# %%
my_list = ["a", "b", "c"]

# %%
my_list.append("d")

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
country[1:]
# Out:
# ['Ghana',
#  'France',
#  'Cameron',
#  'Hungary',
#  'Saudi Arabia',
#  'Israel',
#  ['Jerusalem', 'USA']]

# %%
country[:1]
# Out:
# ['Nigeria']

# %%
country[7]
# Out:
# ['Jerusalem', 'USA']

# %%
country[7][1]
# Out:
# 'USA'

# %%
# Let's make it complex
family = ['Martins', 'Cynthia', 'Nne', ['Chris', 'Collins',['Jude', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]]]

# %%
family
# Out:
# ['Martins',
#  'Cynthia',
#  'Nne',
#  ['Chris', 'Collins', ['Jude', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]]]

# %%
family
# Out:
# ['Martins',
#  'Cynthia',
#  'Nne',
#  ['Chris', 'Collins', ['Jude', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]]]

# %%
family[3][3][1]
# Out:
# ['Gift', 'Jennifer']

# %%
family[3][3][1][1]
# Out:
# 'Jennifer'

# %% [markdown]
# ### Manipulating Lists
#
# #### After creation of lists and subsetting, you must also know how to manipulate a list i.e Chang elements in a list, add elements to a list or remove elements from a list
#
# #### Changing elements in a list

# %%
family
# Out:
# ['Martins',
#  'Cynthia',
#  'Nne',
#  ['Chris', 'Collins', ['Jude', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]]]

# %%
family[3][2][0] = 'Okoye'
family
# Out:
# ['Martins',
#  'Cynthia',
#  'Nne',
#  ['Chris', 'Collins', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]]]

# %%
#Changing a single element
#Changing the name of Collins to  Charlse (Identify the subset Collins and equate it to a new name)
family[3][1] = 'Charlse'
family
# Out:
# ['Martins',
#  'Cynthia',
#  'Nne',
#  ['Chris', 'Charlse', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]]]

# %%
family
# Out:
# ['Martins',
#  'Cynthia',
#  'Nne',
#  ['Chris', 'Charlse', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]]]

# %%
family[1:3] = ["Grace", "Joel"]
family
# Out:
# ['Martins',
#  'Grace',
#  'Joel',
#  ['Chris', 'Charlse', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]]]

# %%
#Changing multiple elements
#To change Martins and Cynthia
family[0:2] = ['Grace', 'John']
family
# Out:
# ['Grace',
#  'John',
#  'Joel',
#  ['Chris', 'Charlse', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]]]

# %% [markdown]
# ### Adding and Removing elements from a list

# %%
family
# Out:
# ['Grace',
#  'John',
#  'Joel',
#  ['Chris', 'Charlse', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]]]

# %%
family + ["Mark", "Joy", "Paul"]
# Out:
# ['Grace',
#  'John',
#  'Joel',
#  ['Chris', 'Charlse', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]],
#  'Mark',
#  'Joy',
#  'Paul']

# %%
#Similar to adding two strings
family + ['Mark', 'Joy']
# Out:
# ['Grace',
#  'John',
#  'Joel',
#  ['Chris', 'Charlse', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]],
#  'Mark',
#  'Joy']

# %%
#You can also save it in another variable
familyNew = family + ['Mark', 'Joy']
familyNew
# Out:
# ['Grace',
#  'John',
#  'Joel',
#  ['Chris', 'Charlse', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]],
#  'Mark',
#  'Joy']

# %%
del(familyNew[3][1])
familyNew
# Out:
# ['Grace',
#  'John',
#  'Joel',
#  ['Chris', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]],
#  'Mark',
#  'Joy']

# %%
family
# Out:
# ['Grace',
#  'John',
#  'Joel',
#  ['Chris', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]]]

# %%
del family[0]

# %%
family
# Out:
# ['John',
#  'Joel',
#  ['Chris', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]]]

# %% [markdown]
# #### To delete elements from a list. Syntax is del(listName[element_loc])

# %%
#To delete John
del(familyNew[1])
familyNew
# Out:
# ['Grace',
#  'Joel',
#  ['Chris', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]],
#  'Mark',
#  'Joy']

# %%
familyNew
# Out:
# ['Grace',
#  'Joel',
#  ['Chris', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]],
#  'Mark',
#  'Joy']

# %%
z2=familyNew + ["Triumph"]
z2
# Out:
# ['Grace',
#  'Joel',
#  ['Chris', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]],
#  'Mark',
#  'Joy',
#  'Triumph']

# %%
familyNew
# Out:
# ['Grace',
#  'Joel',
#  ['Chris', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]],
#  'Mark',
#  'Joy']

# %%
familyNew.append('Triumph')

# %%
familyNew
# Out:
# ['Grace',
#  'Joel',
#  ['Chris', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]],
#  'Mark',
#  'Joy',
#  'Triumph']

# %%
familyNew.insert(1,"Jude")

# %%
familyNew
# Out:
# ['Grace',
#  'Jude',
#  'Joel',
#  ['Chris', ['Okoye', 'Okenna'], ['Chile', ['Gift', 'Jennifer']]],
#  'Mark',
#  'Joy',
#  'Triumph']

# %% [markdown]
# #### Note: When copying lists, by using '=' you are only copying the reference to the list not the actual values themselves, by changing an element in the new list y, it also affects the original list x. However, if you want to retain the elements in the original list, you can use y = list(x). This preserves the element in the original list x, even when an element is changed in y.

# %%
X = ['a', 'b', 'c', 'd']

# %%
# Copying X to y
y = X
y
# Out:
# ['a', 'b', 'c', 'd']

# %%
#Changing element c in y to k
y[2] = 'k'
print(y)
print(X)
# Out:
# ['a', 'b', 'k', 'd']
# ['a', 'b', 'k', 'd']

# %%
#Using list()
y = list(X)
#Changing element d in y to k
y[-1] = 'p'
print(y)
print(X)
# Out:
# ['a', 'b', 'k', 'p']
# ['a', 'b', 'k', 'd']

# %%
y[-3:-1]
# Out:
# ['b', 'k']

# %% [markdown]
# ## Dictionaries
#
# *A dictionary maps a set of objects(Keys) to another set of objects (values). It involves mapping unique keys to values. Dictionaries are unordered, so the order that the keys are added doesnt necessarily reflect what order they may be reported. Note you use {  } to create dictionaries and [  ] to index them*

# %%
colors  = {"Isreal": "Blue", "Meshach": "red", "Triumph": "Pink"}

# %%
colors
# Out:
# {'Isreal': 'Blue', 'Meshach': 'red', 'Triumph': 'Pink'}

# %%
#You use the key to access the value, for example: dictinaryName['key']
colors["Meshach"]
# Out:
# 'red'

# %%
colors['Isreal']
# Out:
# 'Blue'

# %%
new_data = {"house": "building where people"}

# %%
#dictionaries are indexed with their keys
new_data['house']
# Out:
# 'building where people'

# %%
#A dictionary with a list
states = {"Edo": "The capital of Edo states is Benin", 
          "Ekiti": "The capital of Ekiti states is Ado-Ekiti", 
          "Oyo": "The capital of Oyo states is Ibadan", 
          "Lagos": "The capital of Lagos states is Ikeja", 
          "Ogun": "The capital of Ogun states is Abeokuta",
          "USA": ["Califonia", "Texas", "NY", "LAS.V"]}
print(states)
# Out:
# {'Edo': 'The capital of Edo states is Benin', 'Ekiti': 'The capital of Ekiti states is Ado-Ekiti', 'Oyo': 'The capital of Oyo states is Ibadan', 'Lagos': 'The capital of Lagos states is Ikeja', 'Ogun': 'The capital of Ogun states is Abeokuta', 'USA': ['Califonia', 'Texas', 'NY', 'LAS.V']}

# %%
states
# Out:
# {'Edo': 'The capital of Edo states is Benin',
#  'Ekiti': 'The capital of Ekiti states is Ado-Ekiti',
#  'Oyo': 'The capital of Oyo states is Ibadan',
#  'Lagos': 'The capital of Lagos states is Ikeja',
#  'Ogun': 'The capital of Ogun states is Abeokuta',
#  'USA': ['Califonia', 'Texas', 'NY', 'LAS.V']}

# %%
#add a value to the dictionary
states["Ondo"] = "Akure"
print(states)
# Out:
# {'Edo': 'The capital of Edo states is Benin', 'Ekiti': 'The capital of Ekiti states is Ado-Ekiti', 'Oyo': 'The capital of Oyo states is Ibadan', 'Lagos': 'The capital of Lagos states is Ikeja', 'Ogun': 'The capital of Ogun states is Abeokuta', 'USA': ['Califonia', 'Texas', 'NY', 'LAS.V'], 'Ondo': 'Akure'}

# %%
#remove a key and its value
del states['Ondo'] # OR del(states['Ondo'])
states
# Out:
# {'Edo': 'The capital of Edo states is Benin',
#  'Ekiti': 'The capital of Ekiti states is Ado-Ekiti',
#  'Oyo': 'The capital of Oyo states is Ibadan',
#  'Lagos': 'The capital of Lagos states is Ikeja',
#  'Ogun': 'The capital of Ogun states is Abeokuta',
#  'USA': ['Califonia', 'Texas', 'NY', 'LAS.V']}

# %%
#check the length of the dictionary
len(states)
# Out:
# 6

# %%
states["USA"][1]
# Out:
# 'Texas'

# %% [markdown]
# ## Booleans

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %% [markdown]
# ### Functions
#
# A function is a piece of reuseable codes used in solving a particular task. Functions can be called instead of having to write code yourself.
# Methods are attribute of a class (e.g .append(), while a function are called holistically to carry out a certain task e.g print(), max() etc.
#
# We have two (2) types, in-bult and user define function.
# <ol> <li>in-built Functions are simply functions that came with python as default. e.g print(), type() etc.</li>
#     <li>User Define FUnctions: These are functions that are define by individual to avoid repetion of codes.</li>
#
# </ol>
#
# When a variable is defined within a function, such a variable can only be access within the function - this is called a local variable.

# %%
#Example calcuate the sum of numbers in a list
numb = [1,2,3,4,5,6]
#without functions
numbavg = 1+2+3+4+5+6
numbavg
# Out:
# 21

# %%
#with function sum()
numbavg2 = sum(numb)
numbavg2
# Out:
# 21

# %%
#finding the maximum value
max(numb)
# Out:
# 6

# %%
#round function takes 2 imputs, but if you dont specify it rounds up to the nearest whole number
round(1.68456)
# Out:
# 2

# %%
round(1.68)
# Out:
# 2

# %%
# to check the documentation of a function use help()
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %% [markdown]
# #### Methods
# Functions that belong to an object.
# All datatypes are python objects and each object has an associated method to them. For example str - methods: .capitalize(), .replace(); float - methods: .bit_length(), .conjugate(); List - methods: .index(), .count()

# %%
name = 'prosper'

# %%
name.capitalize()
# Out:
# 'Prosper'

# %%
name.replace('r','ct')
# Out:
# 'pctospect'

# %%
#To get the index of an element in a list
country
# Out:
# ['Nigeria',
#  'Ghana',
#  'France',
#  'Cameron',
#  'Hungary',
#  'Saudi Arabia',
#  'Israel',
#  ['Jerusalem', 'USA']]

# %%
country.index("France")
# Out:
# 2

# %%
country.count("Hungary")
# Out:
# 1

# %%
name = 'paul'
name.capitalize()
# Out:
# 'Paul'

# %%
#replaing part of a string paul to paula
name.replace('l', 'la')
# Out:
# 'paula'

# %%
#some methods have do no return a result but carries out the required action.
country.append("Germany")

# %%
country
# Out:
# ['Nigeria',
#  'Ghana',
#  'France',
#  'Cameron',
#  'Hungary',
#  'Saudi Arabia',
#  'Israel',
#  ['Jerusalem', 'USA'],
#  'Germany']

# %% [markdown]
# ### User defined Functions

# %%
#To calculate the sqaure of a number
def square(x):
    return(x**2)

# %%
square(2)
# Out:
# 4

# %%
# To calculate simple interest
def simpleInterest(p,r, t):
    return (p*r*t)/ 100

# %%
simpleInterest(200,5,5)
# Out:
# 50.0

# %%
def cubeRoot(x):
    return((x**4) / 3)

# %%
out = cubeRoot(2)
print(out)
# Out:
# 5.333333333333333

# %%
def congrats(name, cgpa):
    x = print("Congratulations {}! your cgpa is {}".format(name, cgpa))
    return x

# %%
congrats("Grace", 5.0)
# Out:
# Congratulations Grace! your cgpa is 5.0

# %% [markdown]
# #### Task calculate the BMI of a person = W/ H^2

# %% [markdown]
# ## Logic Operator

# %% [markdown]
# <, >, ==, !=, >=, <=

# %% [markdown]
# ### Control Flows

# %% [markdown]
# #### if, elif, else Statements
# Syntax
#
# if condition:
#
#     operation

# %%
if (3<2):
    print("Yep")
else:
    print("No")
# Out:
# No

# %%
if (1<2):
    print("Yep")
# Out:
# Yep

# %%
if (1<2):
    print("First")
else:
    print('last')
# Out:
# First

# %%
if (1>2):
    print("First")
else:
    print('last')
# Out:
# last

# %%
if (1 > 2):
    print("First")
elif 1 == 2:
    print("Middle")
else:
    print('last')
# Out:
# last

# %%
x = 12 
if ((x > 10) and (x % 2 == 0)):
    print("Good number")
elif ((x < 10) and (x % 2 != 0)):
    print("Bad number")
else:
    print("Number is not valuable")
# Out:
# Good number

# %% [markdown]
# ## for Loops

# %% [markdown]
# This is used in situations where you are searching for a data in a large data set with the person's name.

# %% [markdown]
# Note: variables might not be declared but used for example, item, i etc.

# %%
seq = [1, 2, 3, 4]

# %%
for item in seq:
    print ("Yep")
# Out:
# Yep
# Yep
# Yep
# Yep

# %%
for item in seq:
    print (item)
# Out:
# 1
# 2
# 3
# 4

# %%
strg = "this is a this dog"

# %%
for item in strg:
    x = strg.count("this")
print(x)
# Out:
# 2

# %%
names = ["Femi", "Ibukun", "Tola", "George", "Kemi", "Austin", "Peter", "John", "Grace", "Uche", "Paul"]

# %%
names
# Out:
# ['Femi',
#  'Ibukun',
#  'Tola',
#  'George',
#  'Kemi',
#  'Austin',
#  'Peter',
#  'John',
#  'Grace',
#  'Uche',
#  'Paul']

# %%
for i in names:
    if (i == 'Austin'):
            print(i)
# Out:
# Austin

# %%
i
# Out:
# 'Paul'

# %% [markdown]
# ## While Loop - you can read up on this

# %% [markdown]
# ## Map and Filter

# %% [markdown]
# map takes two arguments, the first is what it should do and the list

# %%
#a function to the power of 2
def times2(x):
    return x*2

# %%
lambda x:x*2
# Out:
# <function __main__.<lambda>(x)>

# %%
my_list = [2,5,7,1,9,8]

# %%
y=map(times2, my_list) # map(function_name or lambda, list or value)

# %% [markdown]
# To get an output from the map, put all into a list

# %%
list(y)
# Out:
# [4, 10, 14, 2, 18, 16]

# %% [markdown]
# This is applicable when you are working with a large dataset that has decimals that can be multiplied by 100, you can use a map.

# %%
list(map(lambda x: x*2, my_list))
# Out:
# [4, 10, 14, 2, 18, 16]

# %% [markdown]
# ## Filter

# %% [markdown]
# performs the same function as map, however the output of filter is performed on only the places where the expression in filter holds true

# %%
my_list = [2,5,7,1,9,8]

# %%
y= list(filter(lambda x:x%2 == 0, my_list))

# %%
y
# Out:
# [2, 8]

# %% [markdown]
# ## Congratulations!

# %% [raw]
# Thanks to Grace Ifeoshi.........
